# %% [markdown]
# 1. Create low fidelity- wireframes that demonstrates proper visual hierachy, spacing, contrast , and alignment to ensure readability and usability
# - To create low-b fidelity wireframes demonstrating visual hierachy, spacing , contrast , and alignment, start with a simple sketch, prioritize key elements with larger font sizes or darker shades, use ample white space to group related items and guide the eye, and align elements on a grid for a clean and organized look. focus on functionality and layout over detailed visuals, using placeholder for images and text.
#   - visual hierarchy :
#       - prioritize content : rank all page content and features by importance before you begin.
#       - use size and contrast : make the most important elements, like headlines and calls to action , larger or use darker shades to make them stand out.
#        - employ directional case : use lines, arrows, or even the gaze direction of placeholder figures to guide the users eye to the most important areas.
#   - spacing :
#        - embrace white space : use breathing room around elements to prevent the design from feeling cluttered and overwhelming.
#        - group related items : use spacing to visually group related content and separate unrelated sections.
#        - set ctas apart : give your primary calls to action generus white space around them to make them stand out.
#   - contrast :
#        - use grayscale for focus : use different shades of gray or black to create contrast.
#        - contrast for function : use contrast to distinguish between interactive elements and static content.
#        - reduce distracting contrast : minimize contrast for elements that are not a priority, such as separartors, to keep the users focus on more important content.
#   - alignment :
#        - use a consistent grid : align elements to an invisible grid to create a sense of order and organization
#        - maintain consistency : ensure that similar elements ( like buttons or input fields 0 have the same alignment throughout the design
#        - align to the left for text : for most western - language content, left - alignment text is a standard and readable practice.

# %% [markdown]
# 2. Develop a color palette with at least three primary colors and three secondary colors, ensuring accessibility compliance : use contrast - checking tools to verify compliance with wcag aa and aaa standards.document the contrast ratio results for different color combinations.
# - to develop an accessible color palette with three primary and three secondary colors, we must consider color theory while adhering to web content accessibility guidelines ( wcag ). the key is select colors that have sufficient contrast with each other to ensure readability for people with visual impairments, including color blindness.
# - this palette uses the ryb ( red, yellow, blue ) model for its primary colors, the foundation of subtractive color mixing used in painting and printing.
# - 1. red : a deep, rich red that aintains strong contrast.
# - 2. yellow : a vibrant, dark-toned yellow that provides excellent contrast against lighter backgrounds.
# - 3. blue : a dark, classic navy blue that is highly legible.
# - accessible secondary colors : these colors are created by mixing the primary colors. to ensure accessibility , they are chosen with sufficient darkness or lightness to provide good contrast with the other colors in the palette.
# - 1. orange ( red+yellow) : a warm , deep orange that is easy to distinguish.
# - 2. green ( yellow + blue ) : a dark teal green that avoids the common accessibility issues associated with pure green.
# - 3. purple ( blue + red ) : a deep , vibrant purple with strong visual clarity.
# - ensuring accessibility with contrasts : for a color palette to be accessible, colors must be used in combinations that meet the wcag contrast ratios. thus means using a color contrast checker to test various pairings for text and background use.
# - to use contrast- checking tools for wcag aa and aaa compliance, in put the foreground and background colors into the tool and it will calculate into the tool and it will calculate the contrast ratio and show if the colors pass or fail for each standard. many tools allow you to use hex codes, a color picker, or even an eyedropper to select colors from your webpage or design , and some provide suggestions for compliant colors.
# - a color combinations contrast ratio determines its readability and accessibility , with web content accessibility guidelines ( wcag ) 2.1 specifying different passing scores based on the text size. contrast is the difference in luminance ( brightness ) between two colors and is calculated as a ratio ranging from 1:1 ( no contrasr ) to 2:1:1 ( maximum contrast ).

# %% [markdown]
# 3.  select a simple ui layout to structure, such as a login screen dashboard or product listing page : apply visual hierarchy principles to guide user focus. ensure consistent spacing and alignment to create a structured design
# - of the options, a login screen is the simplest ui layout to structure, as it focuses on a single, clear user flow. a basic login screen only requires a few core components, making it an excellent starting point for learning ui principles.
# - to apply visual hierarchy , user principles like size, color, contrast, typography, and spacing to guide user focus by making more important elements stand out. establish a clear content structure, place key elements strategically, and use whitespace to reduce clutter and improve clarity. this creates an intuitive flow that directs users to the most important actions and information.
# - to ensure consistent spacing and alignment for a structured design, you must establish and follow a systematic approach using grids and a modular scale. this reduce cognitive load for users and creates a professional, organized visual hierarchy.
# - a consistent spacing system ensures that the space between design elements is uniform and deliberate. this reduces clutter and helps define the visual hierarchy.
# - grids are invisible frameworks of columns and rows that provide the underlying structure for aligning elements.

# %% [markdown]
# 4. Test the readability and accessibility of text elements : ensure text color and background contrast meet accessibility guidelines. check button and link visibility for users with visual impairments.
# - you can test the readability and accessibility of text elements using automated tools that analyze sentence and word complexity, such as the fleschkincaid tests, and by using built- in checkers in software like microsoft office. additionally , for web and digital content , you can manually check for accessibility factors like color contrast, clear headings, and descriptive link text.
# - to meet accessibility guidelines, ensure text and background colors have a minimum contrast ratio of 4:5:1 for normal text and 3:1 for large text . use contrast checking tools for verify your color combinations, as poor contrast affects users with low vision or color blindness. aim for a higher ratio if possible, especially on non-solid backgrounds, and remember that black on white offers maximum contrast.
# - to ensure butons and links are visible for users with visual impairments , you must follow best practices for color contrast, size, labeling, and keyboard focus. automated and manual testing methods are used to verify that these elements meet web content accessibility guidelines.
# - good contrast is one of the most important factors for users with low vision or color blindness.
# - keyboard- only users, including many with visual impairments, must be able to see which element is currently selected.
# - the size of interactive elements and text affects visibility and usability , particularly on touch devices or for users with motor impairments.
# - color should never be the only way to convey information or distinguish a link from regular text.
# - users with low vision may use a screen magnifier, and your layout must remain functional at higher zoom levels

# %% [markdown]
# 5. Compile findings into a structured submission that includes : a wireframes showcasing visual hierarchy and structure. a docunment color palette with contrast ration analysis.a brief report explaining the design choices and accessibility considerations.
# -  to compile findings into a structured submission, organize your material according to a logical flow that includes an introduction, detailed methods, clear presentation of results, a discussion of implications, and a concise conclusion. the specific structure can vary depending on the submissions purpose, such as an academic paper, a business report, or a regulatory filing.
# - wireframes showcasing visual hierarchy and structure use basic visual elements like boxes, lines, and placeholder text to map out the layout, content, and functionality of a digital interface without visual distractions like color or images. they are a blueprint that prioritizes elements based on importance, showing how they are arranged and how users will interact with thwm, guiding the user flow and establishing a clear hierarchy of content.
# - a document color palette with contrast ratio analysis ensures readability for all users by adhering to accessibility guidelines like those from the wcag. the palette should be designed to meet a minimum contrast ratio of 4:5:1 for normal text and 3:1 for large text, which is achieved by combining colors with significant luminance differences, like dark text on a light background or vice-versa. tools like coolors or stark can be used to check a chosen palettes combinations.
# - a report on design and accessibility details the why behind design choices, focusing on how the product was created to be useable for everyone. it clarifies the objectives, outlines the specific choices made, and explains how these choices align with accessibility standards like the web content accessibility guidelines ( wcag ). the report is structured to be both informative and easy for various stakeholders to understand.
